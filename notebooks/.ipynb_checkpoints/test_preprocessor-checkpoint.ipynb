# %% [markdown]
# # Preprocessor

# %%
import os, sys
from pathlib import Path

project_path = Path().cwd().parent
os.sys.path.append(project_path.as_posix())

from src.MyModule.utils import *
import pandas as pd

config = load_config()

file_names = config['lung_file_name']

def load_raw_file(file_name):
    '''
    load the raw file from the raw database
    '''
    data_path = project_path.joinpath('data/raw')
    file_path = data_path.joinpath(file_name)
    
    extension = check_extension(file_name)
    try : 
        if extension == 'xlsx' : 
            return pd.read_excel(file_path)

        elif extension == 'csv' : 
            return pd.read_csv(file_path)
    except : 
        raise ValueError("error in reading the file")
        pass

    
def check_extension(file_name : str) : 
    '''
    check the extension for the data
    '''
    assert isinstance(file_name, str), "file name must be string"
    
    try :
        extension = str.split(file_name, '.')[1]
        return extension
    except :
        print("the file name does not contain extension")
        pass

# %%
pt_bsnf_file_name = file_names['lung_pt_bsnf']

pt_bsnf = load_raw_file(pt_bsnf_file_name)
pt_bsnf = pt_bsnf.drop(columns = "CRTN_DT")

# %%
from src.MyModule.preprocessing import *

# %%
staticprocessor = PreprocessStatic(static_data=pt_bsnf, 
                 date_columns=['BSPT_BRYM', 'BSPT_FRST_DIAG_YMD', 'BSPT_FRST_OPRT_YMD', 'BSPT_FRST_ANCN_TRTM_STRT_YMD', 'BSPT_FRST_RDT_STRT_YMD', 'BSPT_DEAD_YMD',
                                      'CENTER_LAST_VST_YMD'], 
                 statndard_date_column='BSPT_BRYM')

# %%
staticprocessor.preprocess()
# Out:
#        CENTER_CD   IRB_APRV_NO  PT_SBST_NO BSPT_SEX_CD  BSPT_BRYM  \
# 0             90  4-2021-05-20  RN00075817           M          0
# 1             90  4-2021-05-20  RN00100695           M          0
# 2             90  4-2021-05-20  RN00104968           F          0
# 3             90  4-2021-05-20  RN00110825           F          0
# 4             90  4-2021-05-20  RN00083644           M          0
# ...          ...           ...         ...         ...        ...
# 11143         90  4-2021-05-20  RN00092310           M          0
# 11144         90  4-2021-05-20  RN00042625           M          0
# 11145         90  4-2021-05-20  RN00052813           F          0
# 11146         90  4-2021-05-20  RN00004040           F          0
# 11147         90  4-2021-05-20  RN00088846           M          0
#
#        BSPT_FRST_DIAG_YMD BSPT_FRST_DIAG_CD  \
# 0                1.110416              C343
# 1                1.147205              C343
# 2                0.730952              C343
# 3               -0.144003              C342
# 4               -0.493625              C341
# ...                   ...               ...
# 11143           -0.461467              C348
# 11144           -0.324603              C343
# 11145           -0.114418              C341
# 11146            1.064366              C343
# 11147            0.463397              C340
#
#                              BSPT_FRST_DIAG_NM  BSPT_IDGN_AGE  \
# 0                 Lower lobe, bronchus or lung       1.141836
# 1                 Lower lobe, bronchus or lung       1.141836
# 2                 Lower lobe, bronchus or lung       0.766025
# 3                Middle lobe, bronchus or lung      -0.173502
# 4                 Upper lobe, bronchus or lung      -0.455361
# ...                                        ...            ...
# 11143  Overlapping lesion of bronchus and lung      -0.455361
# 11144             Lower lobe, bronchus or lung      -0.361408
# 11145             Upper lobe, bronchus or lung      -0.079550
# 11146             Lower lobe, bronchus or lung       1.047883
# 11147                            Main bronchus       0.484167
#
#        BSPT_FRST_OPRT_YMD  ...  BSPT_FRST_ANCN_TRTM_STRT_YMD_mu  \
# 0                     NaN  ...                     1.693319e-16
# 1                     NaN  ...                     1.693319e-16
# 2                0.906418  ...                     1.693319e-16
# 3                     NaN  ...                     1.693319e-16
# 4                     NaN  ...                     1.693319e-16
# ...                   ...  ...                              ...
# 11143                 NaN  ...                     1.693319e-16
# 11144                 NaN  ...                     1.693319e-16
# 11145            0.026539  ...                     1.693319e-16
# 11146                 NaN  ...                     1.693319e-16
# 11147                 NaN  ...                     1.693319e-16
#
#        BSPT_FRST_ANCN_TRTM_STRT_YMD_std  BSPT_FRST_RDT_STRT_YMD_mu  \
# 0                              1.000092               1.554231e-17
# 1                              1.000092               1.554231e-17
# 2                              1.000092               1.554231e-17
# 3                              1.000092               1.554231e-17
# 4                              1.000092               1.554231e-17
# ...                                 ...                        ...
# 11143                          1.000092               1.554231e-17
# 11144                          1.000092               1.554231e-17
# 11145                          1.000092               1.554231e-17
# 11146                          1.000092               1.554231e-17
# 11147                          1.000092               1.554231e-17
#
#        BSPT_FRST_RDT_STRT_YMD_std  BSPT_DEAD_YMD_mu BSPT_DEAD_YMD_std  \
# 0                        1.000091      6.318892e-17          1.000117
# 1                        1.000091      6.318892e-17          1.000117
# 2                        1.000091      6.318892e-17          1.000117
# 3                        1.000091      6.318892e-17          1.000117
# 4                        1.000091      6.318892e-17          1.000117
# ...                           ...               ...               ...
# 11143                    1.000091      6.318892e-17          1.000117
# 11144                    1.000091      6.318892e-17          1.000117
# 11145                    1.000091      6.318892e-17          1.000117
# 11146                    1.000091      6.318892e-17          1.000117
# 11147                    1.000091      6.318892e-17          1.000117
#
#       CENTER_LAST_VST_YMD_mu CENTER_LAST_VST_YMD_std OVRL_SRVL_DTRN_DCNT_mu  \
# 0              -4.315785e-16                1.000045          -4.636884e-17
# 1              -4.315785e-16                1.000045          -4.636884e-17
# 2              -4.315785e-16                1.000045          -4.636884e-17
# 3              -4.315785e-16                1.000045          -4.636884e-17
# 4              -4.315785e-16                1.000045          -4.636884e-17
# ...                      ...                     ...                    ...
# 11143          -4.315785e-16                1.000045          -4.636884e-17
# 11144          -4.315785e-16                1.000045          -4.636884e-17
# 11145          -4.315785e-16                1.000045          -4.636884e-17
# 11146          -4.315785e-16                1.000045          -4.636884e-17
# 11147          -4.315785e-16                1.000045          -4.636884e-17
#
#       OVRL_SRVL_DTRN_DCNT_std
# 0                    1.000045
# 1                    1.000045
# 2                    1.000045
# 3                    1.000045
# 4                    1.000045
# ...                       ...
# 11143                1.000045
# 11144                1.000045
# 11145                1.000045
# 11146                1.000045
# 11147                1.000045
#
# [11148 rows x 36 columns]
