# %%
import pandas as pd
from pathlib import Path
import os, sys

PROJ_PATH = Path().cwd().parents[1]
os.sys.path.append(PROJ_PATH.as_posix())

from src.MyModule.utils import *

config = load_config()

PROJ_PATH = Path(config['path_config']['project_path'])
INPUT_PATH = PROJ_PATH.joinpath('data/processed/2_restore/restore_to_s1')
OUTPUT_PATH = PROJ_PATH.joinpath('data/processed/notebooks')

# %%
s1 = read_file(INPUT_PATH, 'S1_0.1.pkl')

# %%
idx = s1['DEAD_NFRM_DEAD'] == 1
s1[idx]
# Out:
#     PT_SBST_NO       TIME DG_RCNF_RLPS  EX_DIAG_CEA  \
# 10        1000 2222-10-30          NaN          NaN
# 325       1018 2227-03-16          NaN          NaN
# 10        1022 2224-04-01          NaN          NaN
# 318       1025 2223-07-28          NaN          NaN
# 9         1031 2223-08-09          NaN          NaN
# ..         ...        ...          ...          ...
# 345        951 2223-04-19          NaN          NaN
# 963        958 2226-08-26          NaN          NaN
# 344        967 2225-01-26          NaN          NaN
# 11         974 2224-05-18          NaN          NaN
# 743         98 2226-04-09          NaN          NaN
#
#     OPRT_NFRM_OPRT_CLCN_OPRT_KIND_CD OPRT_NFRM_OPRT_CURA_RSCT_CD  \
# 10                               NaN                         NaN
# 325                              NaN                         NaN
# 10                               NaN                         NaN
# 318                              NaN                         NaN
# ...
