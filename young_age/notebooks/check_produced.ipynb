# %%
import pandas as pd
import os, sys
from pathlib import Path

projectPath = Path().cwd().parent
os.sys.path.append(projectPath.as_posix())

# %%
from src.MyModule.utils import *

# %%
config = load_config()

# %% [markdown]
# ## Check Data
# - src/2_produce_data/2_restore.py

# %%
age = 50
randomSeed = 0
epsilon = 0.1

outputPath = projectPath.joinpath(f"data/processed/seed{randomSeed}/2_produce_data/")
dataPath = projectPath.joinpath(f"data/processed/seed{randomSeed}/")

# %%
mldata_path = outputPath.joinpath(f"synthetic_decoded/Synthetic_data_epsilon{epsilon}_{age}.csv")
sample = pd.read_csv(mldata_path)

# %%
sample.filter(like="HM1E")
# Out:
#       IMPT_HM1E_RSLT_NM
# 0                     0
# 1                     2
# 2                     0
# 3                     0
# 4                     0
# ...                 ...
# 5000                  0
# 5001                  0
# 5002                  0
# 5003                  2
# 5004                  2
#
# [5005 rows x 1 columns]

# %%
restore_path = outputPath.joinpath(f"synthetic_restore/Synthetic_data_epsilon{epsilon}_{age}.csv")
restoredSample = pd.read_csv(restore_path, encoding = 'cp949')

# %%
restoredSample['BPTH_SITE_CONT'].unique()
# Out:
# array([nan, 'Colon', 'Rectum', 'Colon and rectum', 'Cecum',
#        'Hepatic flexure', 'Large intestine',
#        'Sigmoidodescending junction', 'Sigmoid colon and rectum',
#        'Ascending colon', 'Colon (AV 25cm)', 'Splenic flexure',
#        'Anastomosis site', 'Rectosigmoid junction', 'Colonic mucosa',
#        'Colon (AV 18cm)', 'Sigmoid colon', 'Descending colon and rectum',
#        'Colon and cecum', 'Clon', 'Recto-sigmoid colon',
#        'Cecum and Rectum', 'Rectum (AV 15-20cm)', 'Terminal ileum',
#        'Tissue from colon'], dtype=object)

# %%
# original data

originalData_path = projectPath.joinpath('data/raw/D0_Handmade_ver2.csv')
original = pd.read_csv(originalData_path)

# %%
original['BPTH_SITE_CONT'].unique()
# Out:
# array(['Colon', 'Cecum', nan, 'Rectum', 'Colon and rectum',
#        'Sigmoid colon and rectum', 'Clon', 'Ascending colon',
#        'Rectosigmoid colon', 'Rectosigmoid junction', 'Sigmoid colon',
#        'Ileocecal valve', 'Large intestine', 'Recto-sigmoid colon',
#        'Sigmoidodescending junction', 'Hepatic flexure', 'Colonic mucosa',
#        'Cecum and Rectum', 'Tissue from colon',
#        'Descending colon and rectum', 'Colon and rectosigmoid junction',
#        'Anastomosis site', 'Terminal ileum', 'Splenic flexure',
#        'Colon and cecum', 'Colon (AV 25cm)', 'Colon (AV 10cm)',
#        'Rectum (AV 15-20cm)', 'Colon (AV 18cm)'], dtype=object)

# %%
preprocess_1_path = projectPath.joinpath(f"data/processed/seed{randomSeed}/1_preprocess/")
encoderPath = preprocess_1_path.joinpath(f"LabelEncoder_{age}.pkl")
encoder_dict_path = preprocess_1_path.joinpath(f"label_dict_{age}.pkl")

encoders = pd.read_pickle(encoderPath)
encoder_dict = pd.read_pickle(encoder_dict_path)

# %%
encoded_data_path = dataPath.joinpath(f"1_preprocess/encoded_D0_to_syn_{age}.csv")
encoded = pd.read_csv(encoded_data_path)

# %% [markdown]
# ## compare with original

# %%
original
# Out:
#       PT_SBST_NO BSPT_SEX_CD  BSPT_IDGN_AGE BSPT_FRST_DIAG_YMD  \
# 0     RN00001096           F             35         2008-01-09
# 1     RN00003729           M             48         2008-01-14
# 2     RN00015427           M             38         2008-01-15
# 3     RN00003816           F             43         2008-01-17
# 4     RN00015199           M             40         2008-01-24
# ...          ...         ...            ...                ...
# 1248  RN00015455           M             29         2020-09-15
# 1249  RN00010979           F             40         2020-09-18
# 1250  RN00015283           M             48         2020-09-21
# 1251  RN00017333           F             44         2020-09-25
# 1252  RN00018474           M             38         2020-10-13
#
#           BSPT_FRST_DIAG_NM BSPT_STAG_CLSF_CD  BSPT_STAG_VL RLPS_DIAG_YMD  \
# 0                     colon                 p             3    2009-04-03
# 1                     colon                 p             1           NaN
# 2                     colon                 p             3           NaN
# 3                     colon                 p             3           NaN
# 4                    rectum                 p             3           NaN
# ...                     ...               ...           ...           ...
# 1248                  colon                 p             1           NaN
# 1249  rectosigmoid junction                 p             2           NaN
# 1250                 rectum                 p             3           NaN
# 1251                  colon                 p             3           NaN
# 1252                  colon                 p             3           NaN
#
#       5YR_RLPS  RLPS  ...  CASB_CSTR_PRPS_NM_7 TRTM_CASB_STRT_YMD7  \
# 0            1     1  ...                  NaN                 NaN
# 1            0     0  ...             Not Data            Not Data
# 2            0     0  ...                  NaN                 NaN
# 3            0     0  ...                  NaN                 NaN
# 4            0     0  ...             Not Data            Not Data
# ...        ...   ...  ...                  ...                 ...
# 1248         0     0  ...             Not Data            Not Data
# 1249         0     0  ...             Not Data            Not Data
# 1250         0     0  ...             Not Data            Not Data
# 1251         0     0  ...             Not Data            Not Data
# 1252         0     0  ...             Not Data            Not Data
#
#       TRTM_CASB_CSTR_YMD2_7 CSTR_CYCL_VL_END_7  CSTR_REGN_NM_8  \
# 0                       NaN                NaN             NaN
# 1                       NaN                NaN             NaN
# 2                       NaN                NaN             NaN
# 3                       NaN                NaN             NaN
# 4                       NaN                NaN             NaN
# ...                     ...                ...             ...
# 1248                    NaN                NaN             NaN
# 1249                    NaN                NaN             NaN
# 1250                    NaN                NaN             NaN
# 1251                    NaN                NaN             NaN
# 1252                    NaN                NaN             NaN
#
#       CSTR_PRPS_NT_8 CASB_CSTR_PRPS_NM_8 TRTM_CASB_STRT_YMD8  \
# 0                NaN                 NaN                 NaN
# 1                NaN                 NaN                 NaN
# 2                NaN                 NaN                 NaN
# 3                NaN                 NaN                 NaN
# 4                NaN                 NaN                 NaN
# ...              ...                 ...                 ...
# 1248             NaN                 NaN                 NaN
# 1249             NaN                 NaN                 NaN
# 1250             NaN                 NaN                 NaN
# 1251             NaN                 NaN                 NaN
# 1252             NaN                 NaN                 NaN
#
#      TRTM_CASB_CSTR_YMD2_8 CSTR_CYCL_VL_END_8
# 0                      NaN                NaN
# 1                      NaN                NaN
# 2                      NaN                NaN
# 3                      NaN                NaN
# 4                      NaN                NaN
# ...                    ...                ...
# 1248                   NaN                NaN
# 1249                   NaN                NaN
# 1250                   NaN                NaN
# 1251                   NaN                NaN
# 1252                   NaN                NaN
#
# [1253 rows x 93 columns]

# %%
restoredCols = set(restoredSample.columns.tolist())
originalCols = set(original.columns.tolist())

# %%
len(restoredCols - originalCols)
# Out:
# 61
