# %%
import pandas as pd
from pathlib import Path
import os, sys

project_path = Path().cwd().absolute().parents[0]
os.sys.path.append(project_path.as_posix())

# %%
from src.MyModule.utils import *

config = load_config()
d0_path = get_path("data/raw/D0_Handmade_ver1.1.xlsx")

# compare with synthetic data

# %%
data = pd.read_excel(d0_path)

# %%
data.head()
# Out:
#    PT_SBST_NO BSPT_SEX_CD  BSPT_IDGN_AGE BSPT_FRST_DIAG_YMD BSPT_FRST_DIAG_NM  \
# 0  RN00001835           M             39         2008-01-07             colon
# 1  RN00001096           F             35         2008-01-09             colon
# 2  RN00005348           F             39         2008-01-09             colon
# 3  RN00003729           M             48         2008-01-14             colon
# 4  RN00015427           M             38         2008-01-15             colon
#
#   BSPT_STAG_CLSF_CD BSPT_STAG_VL RLPS_DIAG_YMD  5YR_RLPS  RLPS  ...  \
# 0               NaN            x           NaT         0     0  ...
# 1                 p            3    2009-04-03         1     1  ...
# 2               NaN            x           NaT         0     0  ...
# 3                 p            1           NaT         0     0  ...
# 4                 p            3           NaT         0     0  ...
#
#    CASB_CSTR_PRPS_NM_7 TRTM_CASB_STRT_YMD7  TRTM_CASB_CSTR_YMD2_7  \
# 0                  NaN                 NaN                    NaN
# 1                  NaN                 NaN                    NaN
# 2             Not Data            Not Data                    NaN
# 3             Not Data            Not Data                    NaN
# 4                  NaN                 NaN                    NaN
#
#   CSTR_CYCL_VL_END_7  CSTR_REGN_NM_8  CSTR_PRPS_NT_8 CASB_CSTR_PRPS_NM_8  \
# 0                NaN             NaN             NaN                 NaN
# 1                NaN             NaN             NaN                 NaN
# 2                NaN             NaN             NaN                 NaN
# 3                NaN             NaN             NaN                 NaN
# 4                NaN             NaN             NaN                 NaN
#
#   TRTM_CASB_STRT_YMD8 TRTM_CASB_CSTR_YMD2_8 CSTR_CYCL_VL_END_8
# 0                 NaN                   NaN                NaN
# 1                 NaN                   NaN                NaN
# 2                 NaN                   NaN                NaN
# 3                 NaN                   NaN                NaN
# 4                 NaN                   NaN                NaN
#
# [5 rows x 93 columns]

# %%
data.filter(like="BSPT")
# Out:
#      BSPT_SEX_CD  BSPT_IDGN_AGE BSPT_FRST_DIAG_YMD      BSPT_FRST_DIAG_NM  \
# 0              M             39         2008-01-07                  colon
# 1              F             35         2008-01-09                  colon
# 2              F             39         2008-01-09                  colon
# 3              M             48         2008-01-14                  colon
# 4              M             38         2008-01-15                  colon
# ...          ...            ...                ...                    ...
# 1496           F             40         2020-09-18  rectosigmoid junction
# 1497           M             48         2020-09-21                 rectum
# 1498           F             44         2020-09-25                  colon
# 1499           F             49         2020-10-08                  colon
# 1500           M             38         2020-10-13                  colon
#
#      BSPT_STAG_CLSF_CD BSPT_STAG_VL BSPT_DEAD_YMD
# 0                  NaN            x           NaT
# 1                    p            3    2010-05-11
# 2                  NaN            x           NaT
# 3                    p            1           NaT
# 4                    p            3           NaT
# ...                ...          ...           ...
# 1496                 p            2           NaT
# 1497                 p            3           NaT
# 1498                 p            3           NaT
# 1499                 c            4           NaT
# 1500                 p            3           NaT
#
# [1501 rows x 7 columns]

# %%
data["BSPT_SEX_CD"].hist()
plt.show()

# %%
data["BSPT_IDGN_AGE"].hist()
plt.show()
