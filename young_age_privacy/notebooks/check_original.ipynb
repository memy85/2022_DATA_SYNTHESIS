# %%
import pandas as pd
from pathlib import Path
import os, sys

project_path = Path().cwd().absolute().parents[0]
os.sys.path.append(project_path.as_posix())

# %%
from src.MyModule.utils import *

config = load_config()
d0_path = get_path("data/raw/D0_Handmade_ver1.1.xlsx")

# compare with synthetic data

synthetic_data_path = get_path("data/processed/2_produce_data/synthetic_decoded/Synthetic_data_epsilon10000_50.csv")
synthetic_data = pd.read_csv(synthetic_data_path)

# %%
data.filter(like = "TRTM")
# Out:
#      TRTM_CASB_STRT_YMD1 TRTM_CASB_CSTR_YMD2_1 TRTM_CASB_STRT_YMD2  \
# 0               20080307              20080913                 NaN
# 1               20080217              20080804                 NaN
# 2               Not Data              Not Data            Not Data
# 3               Not Data              Not Data            Not Data
# 4               20080910              20090304                 NaN
# ...                  ...                   ...                 ...
# 1496            Not Data              Not Data            Not Data
# 1497            Not Data              Not Data            Not Data
# 1498            Not Data              Not Data            Not Data
# 1499            Not Data              Not Data            Not Data
# 1500            Not Data              Not Data            Not Data
#
#      TRTM_CASB_CSTR_YMD2_2 TRTM_CASB_STRT_YMD3 TRTM_CASB_CSTR_YMD2_3  \
# 0                      NaN                 NaN                   NaN
# ...

# %%
data = pd.read_excel(d0_path)

# %%
data["CSTR_REGN_NM_1"].unique()
# Out:
# array(["['FOLFOX']", 'Not Data', "['FOLFOX + AVASTIN']",
#        "['FOLFIRI + AVASTIN']",
#        "['FOLFIRI' 'FOLFIRI + AVASTIN' 'FOLFOX']", "['FOLFIRI']",
#        "['5-FU ± leucovorin']", "['FOLFIRI' 'FOLFIRI + AVASTIN']",
#        "['Other']", "['FOLFIRI' 'FOLFIRI + ERBITUX']",
#        "['FOLFOX + ERBITUX']", "['capecitabline']",
#        "['FOLFOX' 'FOLFOX + AVASTIN']", "['FOLFIRI + ERBITUX']",
#        "['XELOX']", "['FOLFIRI + ERBITUX' 'FOLFOX']",
#        "['FOLFIRI + ERBITUX' 'Other']", "['FOLFIRI' 'FOLFOX']",
#        "['FOLFOX' 'FOLFOX + ERBITUX']",
#        "['FOLFOX + AVASTIN' 'FOLFOX + ERBITUX']",
#        "['FOLFIRI + AVASTIN' 'FOLFIRI + ERBITUX']"], dtype=object)

# %%
synthetic_data.drop(columns = "Unnamed: 0").head().to_csv('/home/wonseok/sample.csv')

# %%
data.filter(like="BSPT")
# Out:
#      BSPT_SEX_CD  BSPT_IDGN_AGE BSPT_FRST_DIAG_YMD      BSPT_FRST_DIAG_NM  \
# 0              M             39         2008-01-07                  colon
# 1              F             35         2008-01-09                  colon
# 2              F             39         2008-01-09                  colon
# 3              M             48         2008-01-14                  colon
# 4              M             38         2008-01-15                  colon
# ...          ...            ...                ...                    ...
# 1496           F             40         2020-09-18  rectosigmoid junction
# 1497           M             48         2020-09-21                 rectum
# 1498           F             44         2020-09-25                  colon
# 1499           F             49         2020-10-08                  colon
# 1500           M             38         2020-10-13                  colon
#
#      BSPT_STAG_CLSF_CD BSPT_STAG_VL BSPT_DEAD_YMD
# ...

# %%
data["BSPT_SEX_CD"].hist()
plt.show()

# %%
from pathlib import Path

data_path = Path().cwd().parents[0].joinpath('data/processed/4_results/')
column_path = data_path.joinpath('sev_columns.pkl')

org_path = Path().cwd().parents[0].joinpath('data/processed/preprocess_1')
train_path = org_path.joinpath('train_ori_50.pkl')
column = pd.read_pickle(column_path)
train = pd.read_pickle(train_path)

# %%
set(train.columns.tolist())- set(column)
# Out:
# {'RLPS', 'RLPS DIFF'}
